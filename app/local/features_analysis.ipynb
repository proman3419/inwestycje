# %%
from preprocessing import load_data, drop_highly_correlated
from seaborn import heatmap

# %%
stock_data, ta_features, preview = load_data("./data/wig_d.csv")
display(preview)
# Out:
#             date      open      high       low     close     volume  \
# 100   2011-09-08  40442.90  40732.76  40001.76  40405.17  117787166
# 101   2011-09-09  40190.27  40253.71  38708.57  38708.57   88364971
# 102   2011-09-12  37969.75  37969.75  37051.55  37437.36  152938899
# 103   2011-09-13  37963.50  38081.49  37120.14  37735.42  120273982
# 104   2011-09-14  37438.64  38144.62  37438.64  37881.76  116739076
# ...          ...       ...       ...       ...       ...        ...
# 2278  2020-06-05  50444.76  51573.79  50444.76  51494.63  102913799
# 2279  2020-06-08  51488.28  51704.68  50806.53  51451.61   88171198
# 2280  2020-06-09  51600.46  51797.65  50738.75  51289.49   95756903
# 2281  2020-06-10  51393.51  51574.08  50896.16  51486.94  128616735
# 2282  2020-06-12  50163.59  50711.94  49106.61  50169.11  121649360
#
#       volume_adi  volume_obv  volume_cmf  volume_fi  ...  momentum_ppo  \
# 100     0.010527    0.031441    0.851364   0.624558  ...      0.577687
# ...

# %%
def show_corr_heatmap(df):
    display(heatmap(df.corr()))
    print(df.shape[1])

# %%
show_corr_heatmap(ta_features)
# Out:
# <Axes: >
# 84

# %%
drop_highly_correlated(ta_features)
show_corr_heatmap(ta_features)
# Out:
# <Axes: >
# 62

# %%
print('\n'.join(sorted(x for x in ta_features.columns)))
# Out:
# momentum_ao
# momentum_ppo_hist
# momentum_pvo
# momentum_pvo_hist
# momentum_pvo_signal
# momentum_roc
# momentum_rsi
# momentum_stoch
# momentum_stoch_rsi
# momentum_stoch_rsi_d
# momentum_stoch_rsi_k
# momentum_stoch_signal
# momentum_tsi
# momentum_uo
# others_dr
# trend_adx
# trend_adx_neg
# trend_adx_pos
# trend_aroon_down
# trend_aroon_ind
# trend_aroon_up
# trend_cci
# trend_dpo
# trend_ichimoku_b
# trend_kst
# trend_kst_diff
# trend_kst_sig
# trend_macd
# trend_macd_diff
# trend_macd_signal
# trend_mass_index
# trend_psar_down_indicator
# trend_psar_up_indicator
# trend_stc
# trend_visual_ichimoku_a
# trend_visual_ichimoku_b
# trend_vortex_ind_diff
# trend_vortex_ind_neg
# trend_vortex_ind_pos
# volatility_atr
# volatility_bbh
# volatility_bbhi
# volatility_bbli
# volatility_bbp
# volatility_bbw
# volatility_dcp
# volatility_dcw
# volatility_kchi
# volatility_kcli
# volatility_kcp
# volatility_kcw
# volatility_ui
# volume_adi
# volume_cmf
# volume_em
# volume_fi
# ...
